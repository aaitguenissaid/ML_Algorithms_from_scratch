# %%
from gradient_descent_3d import Gradient_descent_3d, PlotFunc3D

# %%
model1 = Gradient_descent_3d(-3, -3, 0.1, 10, "p")
model1.fit()
PlotFunc3D(-3, +3, "polynomial", 'p', model1.w1data, model1.w2data, model1.Ldata)

model2 = Gradient_descent_3d(-3, -3, 0.2, 20, 'l')
model2.fit()
PlotFunc3D(-3, +3, "Logistic", 'l', model2.w1data, model2.w2data, model2.Ldata)

model3 = Gradient_descent_3d(-3, -3, 0.5, 20, 'c')
model3.fit()
PlotFunc3D(-3, +3, "Cone", 'c', model3.w1data, model3.w2data, model3.Ldata)

model4 = Gradient_descent_3d(-2, -2, 0.02, 20, 'e')
model4.fit()
PlotFunc3D(-2, +2, "Exponential", 'e', model4.w1data, model4.w2data, model4.Ldata)

model5 = Gradient_descent_3d(0.5, 0, 0.1, 20, 'b')
model5.fit()
PlotFunc3D(-5, 5, "cosine normarlized", 'b', model5.w1data, model5.w2data, model5.Ldata)

model6 = Gradient_descent_3d(-0.05, -.8, 0.1, 1000, 'bu')
model6.fit()
PlotFunc3D(-1, 1, "Bumps", 'bu', model6.w1data, model6.w2data, model6.Ldata)

model7 = Gradient_descent_3d(1.5, -1.5, 0.01, 1000, 'r')
model7.fit()
PlotFunc3D(-3, 3., "Rosenbrock", 'r', model7.w1data, model7.w2data, model7.Ldata)
